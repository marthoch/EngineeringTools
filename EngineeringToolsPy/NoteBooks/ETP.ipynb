# %% [markdown]
# # Testing EngineeringTools.special.etp

# %%
import sys
# download form https://github.com/marthoch/EngineeringTools
sys.path.insert(0, r'C:\data\GitHub\EngineeringTools\EngineeringToolsPy\src')

import EngineeringTools as ET
import EngineeringTools.quantities as ETQ
import EngineeringTools.tools as ETtools
ETQ.Quantity.set_displayUnitSystem('mechanicalEngineering')
import EngineeringTools.special as ETspecial

# %%
ETspecial.ETPHydrHubShaftConnection.read_database()
ETspecial.ETPHydrHubShaftConnection.list_all()
# Out:
#                         kind    d    D     D1     D2    L   L1      T     FA  \
# name
# ETP-EXPRESS 15   ETP-EXPRESS   15   18   46.0   48.9   25   39     46    5.1
# ETP-EXPRESS 19   ETP-EXPRESS   19   23   50.5   53.0   28   42     85    7.3
# ETP-EXPRESS 20   ETP-EXPRESS   20   24   51.5   54.1   30   44    110    9.1
# ETP-EXPRESS 22   ETP-EXPRESS   22   27   55.5   60.5   32   46    130    9.6
# ETP-EXPRESS 24   ETP-EXPRESS   24   29   57.5   62.3   33   47    190   13.0
# ETP-EXPRESS 25   ETP-EXPRESS   25   30   58.0   62.9   35   49    230   15.0
# ETP-EXPRESS 28   ETP-EXPRESS   28   34   63.0   69.6   38   52    280   16.0
# ETP-EXPRESS 30   ETP-EXPRESS   30   36   64.5   71.0   40   54    380   21.0
# ETP-EXPRESS 32   ETP-EXPRESS   32   39   68.5   77.7   42   56    440   22.0
# ETP-EXPRESS 35   ETP-EXPRESS   35   42   73.0   85.1   45   59    640   30.0
# ETP-EXPRESS 38   ETP-EXPRESS   38   46   84.5   89.5   52   72    890   38.0
# ETP-EXPRESS 40   ETP-EXPRESS   40   48   86.5   91.2   55   75   1100   45.0
# ETP-EXPRESS 42   ETP-EXPRESS   42   51   89.0   93.5   56   76   1100   43.0
# ETP-EXPRESS 45   ETP-EXPRESS   45   54   93.0  100.3   58   78   1400   51.0
# ETP-EXPRESS 48   ETP-EXPRESS   48   59   97.0  103.8   59   79   1700   57.0
# ETP-EXPRESS 50   ETP-EXPRESS   50   60   98.5  105.1   60   80   1900   63.0
# ETP-EXPRESS 55   ETP-EXPRESS   55   67  106.0  115.9   65   85   2400   71.0
# ETP-EXPRESS 60   ETP-EXPRESS   60   73  115.5  132.7   70   90   3300   90.0
# ETP-EXPRESS 65   ETP-EXPRESS   65   79  120.5  137.0   75   95   4400  112.0
# ETP-EXPRESS 70   ETP-EXPRESS   70   85  135.5  153.9   85  109   5600  130.0
# ETP-EXPRESS 80   ETP-EXPRESS   80   97  145.5  162.6   95  119   8700  180.0
# ETP-EXPRESS 90   ETP-EXPRESS   90  109  155.5  171.7  105  129  12000  220.0
# ETP-EXPRESS 100  ETP-EXPRESS  100  121  166.0  181.0  115  139  17000  280.0
# ETP-TECHNO 15     ETP-TECHNO   15   19   52.0   54.0   25   41     50    5.0
# ETP-TECHNO 20     ETP-TECHNO   20   25   59.0   61.0   30   46    145   12.0
# ETP-TECHNO 25     ETP-TECHNO   25   32   70.0   72.0   35   55    250   16.0
# ETP-TECHNO 30     ETP-TECHNO   30   38   75.0   79.0   40   60    500   26.0
# ETP-TECHNO 32     ETP-TECHNO   32   41   79.0   83.0   42   62    510   25.0
# ETP-TECHNO 35     ETP-TECHNO   35   44   84.0   90.0   45   65    740   34.0
# ETP-TECHNO 40     ETP-TECHNO   40   52   91.0   98.0   55   75   1200   47.0
# ETP-TECHNO 45     ETP-TECHNO   45   56   96.0  105.0   58   78   1700   62.0
# ETP-TECHNO 50     ETP-TECHNO   50   65  110.0  117.0   60   85   2250   71.0
# ETP-TECHNO 60     ETP-TECHNO   60   75  125.0  154.0   70   95   4400  119.0
# ETP-TECHNO 70     ETP-TECHNO   70   90  140.0  156.0   85  110   7000  158.0
# ETP-TECHNO 75     ETP-TECHNO   75   95  148.0  164.0   90  115   8600  183.0
# ETP-TECHNO 80     ETP-TECHNO   80  100  156.0  173.0   95  123  10900  218.0
# ETP-TECHNO 90     ETP-TECHNO   90  112  166.0  180.0  105  133  15500  277.0
# ETP-TECHNO 100    ETP-TECHNO  100  125  177.0  192.0  115  143  21000  335.0
# ETP-TECHNO 110    ETP-TECHNO  110  138  187.0  202.0  125  153  28000  410.0
# ETP-TECHNO 120    ETP-TECHNO  120  150  198.0  217.0  135  163  29000  393.0
# ETP-TECHNO 130    ETP-TECHNO  130  163  208.0  226.0  135  163  32000  393.0
#
#                    FR Thread     R   N  Tt      J      m
# name
# ETP-EXPRESS 15    0.5    M10  15.1   5   5   0.04   0.16
# ETP-EXPRESS 19    1.0    M10  17.4   5   5   0.06   0.20
# ETP-EXPRESS 20    1.0    M10    18   5   5   0.07   0.21
# ETP-EXPRESS 22    1.2    M10  19.3   5   5   0.10   0.25
# ETP-EXPRESS 24    1.4    M10  20.3   5   5   0.11   0.27
# ETP-EXPRESS 25    1.5    M10  20.8   5   5   0.12   0.27
# ETP-EXPRESS 28    1.8    M10  22.6   5   5   0.17   0.34
# ETP-EXPRESS 30    2.0    M10  23.6   5   5   0.19   0.35
# ETP-EXPRESS 32    2.2    M10  24.8   5   5   0.25   0.42
# ETP-EXPRESS 35    2.5    M10  26.4   5   5   0.32   0.48
# ETP-EXPRESS 38    2.8    M16    31   8  21   0.76   0.84
# ETP-EXPRESS 40    3.0    M16    32   8  21   0.84   0.88
# ETP-EXPRESS 42    3.2    M16  33.2   8  21   0.97   0.96
# ETP-EXPRESS 45    3.5    M16  34.8   8  21   1.17   1.05
# ETP-EXPRESS 48    4.0    M16  36.8   8  21   1.46   1.21
# ETP-EXPRESS 50    4.5    M16  37.5   8  21   1.52   1.20
# ETP-EXPRESS 55    5.0    M16  40.5   8  21   2.18   1.50
# ETP-EXPRESS 60    5.3    M16  43.3   8  21   3.17   1.85
# ETP-EXPRESS 65    5.6    M16  46.1   8  21    4.1   2.13
# ETP-EXPRESS 70    6.4    M20  50.8  10  39   7.12   3.04
# ETP-EXPRESS 80    7.5    M20  56.3  10  39  10.35   3.75
# ETP-EXPRESS 90    8.6    M20  61.8  10  39  15.20   4.80
# ETP-EXPRESS 100   9.7    M20  67.3  10  39  21.90   5.90
# ETP-TECHNO 15     1.0    M12    16   6  10   0,09   0,25
# ETP-TECHNO 20     2.0    M12    19   6  10   0,15   0,32
# ETP-TECHNO 25     3.0    M14    24   6  16   0,38   0,58
# ETP-TECHNO 30     4.0    M14  25,5   6  16   0,54   0,69
# ETP-TECHNO 32     4.0    M14  27,5   6  16   0,64   0,78
# ETP-TECHNO 35     5.0    M16  29,2   8  24   0,75   0,84
# ETP-TECHNO 40     6.0    M16  32,7   8  24    1,3   1,18
# ETP-TECHNO 45     7.0    M16  34,7   8  24    1,5   1,24
# ETP-TECHNO 50     9.0    M20  40,5  10  40    2,3   1,64
# ETP-TECHNO 60    12.0    M20  46,3  10  40      5   2,51
# ETP-TECHNO 70    13.0    M20    53  10  40    8,9   3,65
# ETP-TECHNO 75    14.0    M20  55,3  10  40     12   4,20
# ETP-TECHNO 80    15.0    M22  58,7  10  60     15   4,85
# ETP-TECHNO 90    17.0    M22  63,3  10  60     22   5,44
# ETP-TECHNO 100   19.0    M22  69,6  10  60     33   6,18
# ETP-TECHNO 110   21.0    M22  75,1  10  60     43   7,08
# ETP-TECHNO 120   23.0    M22  80,9  10  50     54   9,96
# ETP-TECHNO 130   25.0    M22  86,3  10  46     75  10,86

# %%
ETspecial.ETPHydrHubShaftConnection('ETP-EXPRESS 50')
# Out:
# ETP ClampingElement
# name:           ETP_EXPRESS ETP-EXPRESS 50
# rod diameter:           50.000 mm (Distance)
# outer diameter:         60.000 mm (Distance)
# length:                 60.000 mm (Distance)
# lengthTotal:            80.000 mm (Distance)
# Torque:              1 900     N.m (Torque)

# %%
ETspecial.ETPHydrHubShaftConnection.search(d=50)
# Out:
#                        kind   d   D     D1     D2   L  L1     T    FA   FR  \
# name
# ETP-EXPRESS 50  ETP-EXPRESS  50  60   98.5  105.1  60  80  1900  63.0  4.5
# ETP-TECHNO 50    ETP-TECHNO  50  65  110.0  117.0  60  85  2250  71.0  9.0
#
#                Thread     R   N  Tt     J     m
# name
# ETP-EXPRESS 50    M16  37.5   8  21  1.52  1.20
# ETP-TECHNO 50     M20  40,5  10  40   2,3  1,64

# %%
ETspecial.ETPHydrHubShaftConnection.search(d=ETQ.Distance(50,'mm'))
# Out:
#                        kind   d   D     D1     D2   L  L1     T    FA   FR  \
# name
# ETP-EXPRESS 50  ETP-EXPRESS  50  60   98.5  105.1  60  80  1900  63.0  4.5
# ETP-TECHNO 50    ETP-TECHNO  50  65  110.0  117.0  60  85  2250  71.0  9.0
#
#                Thread     R   N  Tt     J     m
# name
# ETP-EXPRESS 50    M16  37.5   8  21  1.52  1.20
# ETP-TECHNO 50     M20  40,5  10  40   2,3  1,64

# %%
ETspecial.ETPHydrHubShaftConnection.search(D=ETQ.Distance(60,'mm'))
# Out:
#                        kind   d   D    D1     D2   L  L1     T    FA   FR  \
# name
# ETP-EXPRESS 50  ETP-EXPRESS  50  60  98.5  105.1  60  80  1900  63.0  4.5
#
#                Thread     R  N  Tt     J     m
# name
# ETP-EXPRESS 50    M16  37.5  8  21  1.52  1.20

# %%
ETspecial.ETPHydrHubShaftConnection.search(minT=10000)
# Out:
#                         kind    d    D     D1     D2    L   L1      T     FA  \
# name
# ETP-TECHNO 80     ETP-TECHNO   80  100  156.0  173.0   95  123  10900  218.0
# ETP-EXPRESS 90   ETP-EXPRESS   90  109  155.5  171.7  105  129  12000  220.0
# ETP-TECHNO 90     ETP-TECHNO   90  112  166.0  180.0  105  133  15500  277.0
# ETP-EXPRESS 100  ETP-EXPRESS  100  121  166.0  181.0  115  139  17000  280.0
# ETP-TECHNO 100    ETP-TECHNO  100  125  177.0  192.0  115  143  21000  335.0
# ETP-TECHNO 110    ETP-TECHNO  110  138  187.0  202.0  125  153  28000  410.0
# ETP-TECHNO 120    ETP-TECHNO  120  150  198.0  217.0  135  163  29000  393.0
# ETP-TECHNO 130    ETP-TECHNO  130  163  208.0  226.0  135  163  32000  393.0
#
#                    FR Thread     R   N  Tt      J      m
# name
# ETP-TECHNO 80    15.0    M22  58,7  10  60     15   4,85
# ETP-EXPRESS 90    8.6    M20  61.8  10  39  15.20   4.80
# ETP-TECHNO 90    17.0    M22  63,3  10  60     22   5,44
# ETP-EXPRESS 100   9.7    M20  67.3  10  39  21.90   5.90
# ETP-TECHNO 100   19.0    M22  69,6  10  60     33   6,18
# ETP-TECHNO 110   21.0    M22  75,1  10  60     43   7,08
# ETP-TECHNO 120   23.0    M22  80,9  10  50     54   9,96
# ETP-TECHNO 130   25.0    M22  86,3  10  46     75  10,86

# %%
ETspecial.ETPHydrHubShaftConnection.search(minT=ETQ.Torque(10000, 'N.m'))
# Out:
#                         kind    d    D     D1     D2    L   L1      T     FA  \
# name
# ETP-TECHNO 80     ETP-TECHNO   80  100  156.0  173.0   95  123  10900  218.0
# ETP-EXPRESS 90   ETP-EXPRESS   90  109  155.5  171.7  105  129  12000  220.0
# ETP-TECHNO 90     ETP-TECHNO   90  112  166.0  180.0  105  133  15500  277.0
# ETP-EXPRESS 100  ETP-EXPRESS  100  121  166.0  181.0  115  139  17000  280.0
# ETP-TECHNO 100    ETP-TECHNO  100  125  177.0  192.0  115  143  21000  335.0
# ETP-TECHNO 110    ETP-TECHNO  110  138  187.0  202.0  125  153  28000  410.0
# ETP-TECHNO 120    ETP-TECHNO  120  150  198.0  217.0  135  163  29000  393.0
# ETP-TECHNO 130    ETP-TECHNO  130  163  208.0  226.0  135  163  32000  393.0
#
#                    FR Thread     R   N  Tt      J      m
# name
# ETP-TECHNO 80    15.0    M22  58,7  10  60     15   4,85
# ETP-EXPRESS 90    8.6    M20  61.8  10  39  15.20   4.80
# ETP-TECHNO 90    17.0    M22  63,3  10  60     22   5,44
# ETP-EXPRESS 100   9.7    M20  67.3  10  39  21.90   5.90
# ETP-TECHNO 100   19.0    M22  69,6  10  60     33   6,18
# ETP-TECHNO 110   21.0    M22  75,1  10  60     43   7,08
# ETP-TECHNO 120   23.0    M22  80,9  10  50     54   9,96
# ETP-TECHNO 130   25.0    M22  86,3  10  46     75  10,86

# %%
ETspecial.ETPHydrHubShaftConnection(d=ETQ.Distance(50, 'mm'))
# Out:
#                        kind   d   D     D1     D2   L  L1     T    FA   FR  \
# name
# ETP-EXPRESS 50  ETP-EXPRESS  50  60   98.5  105.1  60  80  1900  63.0  4.5
# ETP-TECHNO 50    ETP-TECHNO  50  65  110.0  117.0  60  85  2250  71.0  9.0
#
#                Thread     R   N  Tt     J     m
# name
# ETP-EXPRESS 50    M16  37.5   8  21  1.52  1.20
# ETP-TECHNO 50     M20  40,5  10  40   2,3  1,64
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-9-b0e5d99c81d4> in <module>
# ----> 1 ETspecial.ETPHydrHubShaftConnection(d=ETQ.Distance(50, 'mm'))
#
# C:\data\GitHub\EngineeringTools\EngineeringToolsPy\src\EngineeringTools\special\etp.py in __init__(self, name, kind, d, D, minT)
#     140             else:
#     141                 print(datasets)
# --> 142                 raise Exception('More or less than one products fit the parameters, use search method')
#     143         self.dataset = dataset
#     144         self.name   = dataset.name
#
# Exception: More or less than one products fit the parameters, use search method

# %%
d = ETspecial.ETPHydrHubShaftConnection.search(d=ETQ.Distance(50, 'mm'))
d

# %%
d.iloc[0].name

# %%
ETspecial.ETPHydrHubShaftConnection(d.iloc[0].name)

# %%
hsc = ETspecial.ETPHydrHubShaftConnection(d.iloc[0].name)
hsc

# %%
hsc.inner_diameter

# %%
hsc.torque
